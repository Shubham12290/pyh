# %% [markdown]
# <a href="https://colab.research.google.com/github/Shubham12290/pyh/blob/main/Untitled21.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
price=[2,3,4,5]
year=[2022,2021,2024,2025]
plt.xlim(0,7500)
plt.plot(year,price)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd

# %%
sub

# %%
sub=pd.read_csv("/content/subs.csv")
sub

# %%
sub.sort_values(by="Subscribers gained")

# %%
import pandas as pd

sub = pd.read_csv("/content/subs.csv")
sub
# Out:
#      Subscribers gained
# 0                    48
# 1                    57
# 2                    40
# 3                    43
# 4                    44
# ..                  ...
# 360                 231
# 361                 226
# 362                 155
# 363                 144
# 364                 172
#
# [365 rows x 1 columns]

# %%
sub = pd.read_csv("/kohli_ipl.csv", index_col="m").squeeze("columns")
sub

# %%
sub=pd.read_csv("/kohli_ipl.csv")

# %%
sub

# %%
df = pd.read_csv("/kohli_ipl.csv")
df.rename(columns={"match no": "match_no", "run": "runs"}, inplace=True)

sub = df.set_index("match_no").squeeze("columns")

# %%
sub

# %%
sub = pd.read_csv("/kohli_ipl.csv".squeeze("columns")

sub

# %%
sub.head(10
         )

# %%
sub

# %%
m=sub.value_counts()

# %%
import pandas as pd
movie=pd.read_csv("/content/bollywood.csv")

# %%
movie.mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_25495/215642755.py in <cell line: 0>()
# ----> 1 movie.mean()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   11691         **kwargs,
#   11692     ):
# > 11693         result = super().mean(axis, skipna, numeric_only, **kwargs)
#   11694         if isinstance(result, Series):
#   11695             result = result.__finalize__(self, method="mean")
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   12418         **kwargs,
#   12419     ) -> Series | float:
# > 12420         return self._stat_function(
#   12421             "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12422         )
#
# ...

# %%
movie.sum()
# Out:
# movie    Uri: The Surgical StrikeBattalion 609The Accid...
# lead     Vicky KaushalVicky AhujaAnupam KherEmraan Hash...
# dtype: object

# %%
movie.sort_values(by="movie")
#vk.sort_values(by="runs")

# %%
vk
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_5143/502764356.py in <cell line: 0>()
# ----> 1 vk
#
# NameError: name 'vk' is not defined

# %%
vk.sort_index()
vk
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_5143/1863319645.py in <cell line: 0>()
# ----> 1 vk.sort_index()
#       2 vk
#
# NameError: name 'vk' is not defined

# %%
vk=pd.read_csv("/content/kohli_ipl.csv")
vk
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_5143/2727134804.py in <cell line: 0>()
# ----> 1 vk=pd.read_csv("/content/kohli_ipl.csv")
#       2 vk
#
# NameError: name 'pd' is not defined

# %%
vk.sort_values(by="runs",ascending=False).head(1).values[0]

# %%
k=vk.sort_values(by="runs",ascending=False).head(1).values[0]

# %%
movie.sort_values(by="lead",inplace=True)
movie

# %%
movie

# %%
movies.sort_values()

# %%
sub

# %%
vk.sort_values(by="runs",ascending=False,inplace=True)
vk

# %%
vk
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_25495/502764356.py in <cell line: 0>()
# ----> 1 vk
#
# NameError: name 'vk' is not defined

# %%
movie.count()
# Out:
# movie    1500
# lead     1500
# dtype: int64

# %%
vk
# Out:
#      match_no  runs
# 0           1     1
# 1           2    23
# 2           3    13
# 3           4    12
# 4           5     1
# ..        ...   ...
# 210       211     0
# 211       212    20
# 212       213    73
# 213       214    25
# 214       215     7
#
# [215 rows x 2 columns]

# %%
vk.product()

# %%
sub.count()
# Out:
# Subscribers gained    365
# dtype: int64

# %%
df.sum()
# Out:
# Age    42
# dtype: int64

# %%
sub.median()
# Out:
# Subscribers gained    123.0
# dtype: float64

# %%
import pandas as pd

df = pd.DataFrame({
        "Age": [20, 22]
})

#df.insert(1, "City", ["Delhi", "Patna"])

print(df)
# Out:
#    Age
# 0   20
# 1   22

# %%
df.median()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_25495/530051474.py in <cell line: 0>()
# ----> 1 df.median()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in median(self, axis, skipna, numeric_only, **kwargs)
#   11704         **kwargs,
#   11705     ):
# > 11706         result = super().median(axis, skipna, numeric_only, **kwargs)
#   11707         if isinstance(result, Series):
#   11708             result = result.__finalize__(self, method="median")
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in median(self, axis, skipna, numeric_only, **kwargs)
#   12429         **kwargs,
#   12430     ) -> Series | float:
# > 12431         return self._stat_function(
#   12432             "median", nanops.nanmedian, axis, skipna, numeric_only, **kwargs
#   12433         )
#
# ...

# %%
movie.mode()
# Out:
#                      movie          lead
# 0                   Andaaz  Akshay Kumar
# 1           Gabbar Is Back           NaN
# 2  Tanu Weds Manu: Returns           NaN

# %%
sub.std()
# Out:
# Subscribers gained    62.675023
# dtype: float64

# %%
vk.mode()
# Out:
#      match_no  runs
# 0           1   0.0
# 1           2   NaN
# 2           3   NaN
# 3           4   NaN
# 4           5   NaN
# ..        ...   ...
# 210       211   NaN
# 211       212   NaN
# 212       213   NaN
# 213       214   NaN
# 214       215   NaN
#
# [215 rows x 2 columns]

# %%
df
# Out:
#    Age
# 0   20
# 1   22

# %%
vk.std()
# Out:
# match_no    62.209324
# runs        26.229801
# dtype: float64

# %%
sub.var()
# Out:
# Subscribers gained    3928.158513
# dtype: float64

# %%
df.var()
# Out:
# Age    2.0
# dtype: float64

# %%
movie.min()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_25495/657415701.py in <cell line: 0>()
# ----> 1 movie[0]
#
# ...

# %%
df
# Out:
#    Age
# 0   20
# 1   22

# %%
sub.describe()
# Out:
#        Subscribers gained
# count          365.000000
# mean           135.643836
# std             62.675023
# min             33.000000
# 25%             88.000000
# 50%            123.000000
# 75%            177.000000
# max            396.000000

# %%
import pandas as pd

df = pd.DataFrame({
    "ID": [101, 102, 103, 104, 105],
    "Name": ["Ram", "Shyam", "Aman", "Ravi", "Neha"],
    "Age": [20, 22, 21, 23, 20],
    "City": ["Patna", "Delhi", "Mumbai", "Kolkata", "Lucknow"],
    "Salary": [30000, 45000, 40000, 50000, 35000]
})

print(df)
# Out:
#     ID   Name  Age     City  Salary
# 0  101    Ram   20    Patna   30000
# 1  102  Shyam   22    Delhi   45000
# 2  103   Aman   21   Mumbai   40000
# 3  104   Ravi   23  Kolkata   50000
# 4  105   Neha   20  Lucknow   35000

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_5143/2527378121.py in <cell line: 0>()
# ----> 1 df[df>=102].size
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/ops/common.py in new_method(self, other)
#      74         other = item_from_zerodim(other)
#      75
# ---> 76         return method(self, other)
#      77
#      78     return new_method
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/arraylike.py in __ge__(self, other)
#      58     @unpack_zerodim_and_defer("__ge__")
#      59     def __ge__(self, other):
# ---> 60         return self._cmp_method(other, operator.ge)
#      61
#      62     # -------------------------------------------------------------
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in _cmp_method(self, other, op)
#    7898
#    7899         # See GH#4537 for discussion of scalar op behavior
# ...

# %%
x=pd.Series([11,12,13,15,9])
x[1]
# Out:
# np.int64(12)

# %%
vk
# Out:
#      match_no  runs
# 0           1     1
# 1           2    23
# 2           3    13
# 3           4    12
# 4           5     1
# ..        ...   ...
# 210       211     0
# 211       212    20
# 212       213    73
# 213       214    25
# 214       215     7
#
# [215 rows x 2 columns]

# %%
vk.iloc[[1,2,5],:-5]
# Out:
# Empty DataFrame
# Columns: []
# Index: [1, 2, 5]

# %%
vk
# Out:
#      match_no  runs
# 0           1     1
# 1           2    23
# 2           3    13
# 3           4    12
# 4           5     1
# ..        ...   ...
# 210       211     0
# 211       212    20
# 212       213    73
# 213       214    25
# 214       215     7
#
# [215 rows x 2 columns]

# %%
movie[-5:]
# Out:
#                        movie              lead
# 1495  Hum Tumhare Hain Sanam    Shah Rukh Khan
# 1496     Aankhen (2002 film)  Amitabh Bachchan
# 1497         Saathiya (film)      Vivek Oberoi
# 1498          Company (film)        Ajay Devgn
# 1499    Awara Paagal Deewana      Akshay Kumar

# %%
vk[::2]
# Out:
#      match_no  runs
# 0           1     1
# 2           3    13
# 4           5     1
# 6           7    34
# 8           9    21
# ..        ...   ...
# 206       207     0
# 208       209    58
# 210       211     0
# 212       213    73
# 214       215     7
#
# [108 rows x 2 columns]

# %%
 vk[-10:]
# Out:
#      match_no  runs
# 205       206     0
# 206       207     0
# 207       208     9
# 208       209    58
# 209       210    30
# 210       211     0
# 211       212    20
# 212       213    73
# 213       214    25
# 214       215     7

# %%
vk.iloc[[1,5,3]]
# Out:
#    match_no  runs
# 1         2    23
# 5         6     9
# 3         4    12

# %%
vk["runs"]=10
vk
# Out:
#      match_no  runs   0   1
# 0           1    10  10  10
# 1           2    10  10  10
# 2           3    10  10  10
# 3           4    10  10  10
# 4           5    10  10  10
# ..        ...   ...  ..  ..
# 210       211    10  10  10
# 211       212    10  10  10
# 212       213    10  10  10
# 213       214    10  10  10
# 214       215    10  10  10
#
# [215 rows x 4 columns]

# %%
df=pd.DataFrame({"subject":["maths","english","science","hindi"],
                "Marks":[95,95,98,85]})

# %%
import pandas as pd

df = pd.DataFrame({
    "Name": ["Ram", "Shyam"],
    "Age": [20, 22]
})

df.insert(1, "City", ["Patna", "Delhi"])

print(df)

# %%
df["Marks"]=df["Marks"].replace(100,95)

# %%
df
# Out:
#    subject  Marks    1
# 0    maths     95  100
# 1  english     95  100
# 2  science     98  100
# 3    hindi     85  100

# %%
df.loc[0,"Marks"]=99
df
# Out:
#     ID   Name  Age     City  Salary  Marks
# 0  102    Ram   20    Patna   30000   99.0
# 1  102  Shyam   22    Delhi   45000    NaN
# 2  103   Aman   21   Mumbai   40000    NaN
# 3  104   Ravi   23  Kolkata   50000    NaN
# 4  105   Neha   20  Lucknow   35000    NaN

# %%
df
# Out:
#     ID   Name  Age     City  Salary  Marks
# 0  102    Ram   20    Patna   30000   99.0
# 1  102  Shyam   22    Delhi   45000    NaN
# 2  103   Aman   21   Mumbai   40000    NaN
# 3  104   Ravi   23  Kolkata   50000    NaN
# 4  105   Neha   20  Lucknow   35000    NaN

# %%
#df.loc[0,"ID"]>102
(df["ID"]>103)
#(df["Marks"] == 50).sum()
df["ID"]>102
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4     True
# Name: ID, dtype: bool

# %%
df.l

# %%
df
# Out:
#     ID   Name  Age     City  Salary  Marks
# 0  102    Ram   20    Patna   30000   99.0
# 1  102  Shyam   22    Delhi   45000    NaN
# 2  103   Aman   21   Mumbai   40000    NaN
# 3  104   Ravi   23  Kolkata   50000    NaN
# 4  105   Neha   20  Lucknow   35000    NaN

# %%
df.loc[0,"Marks"]=100

# %%
df
# Out:
#    subject  Marks    1
# 0    maths    100  100
# 1  english     95  100
# 2  science     98  100
# 3    hindi     85  100

# %%
vk.loc[0,"runs"]=9

# %%
vk.head()
# Out:
#    match_no  runs   0   1
# 0         1     9  10  10
# 1         2    10  10  10
# 2         3    10  10  10
# 3         4    10  10  10
# 4         5    10  10  10

# %%
vk.loc[4,"runs"]=100

# %%
vk
# Out:
#       match_no   runs     0     1  Marks      4
# 0         98.0   98.0  98.0  98.0   98.0    NaN
# 1         98.0   98.0  98.0  98.0   98.0    NaN
# 2          3.0   10.0  10.0  10.0    NaN    NaN
# 3          4.0   10.0  10.0  10.0    NaN    NaN
# 4         98.0  100.0  98.0  98.0   98.0    NaN
# ...        ...    ...   ...   ...    ...    ...
# 211      212.0   10.0  10.0  10.0    NaN    NaN
# 212      213.0   10.0  10.0  10.0    NaN    NaN
# 213      214.0   10.0  10.0  10.0    NaN    NaN
# 214      215.0   10.0  10.0  10.0    NaN    NaN
# runs       NaN    NaN   NaN   NaN    NaN  100.0
#
# [216 rows x 6 columns]

# %%
vk.loc[0,0]=100

# %%
vk
# Out:
#      match_no  runs   0   1  Marks
# 0           1   100  10  10  100.0
# 1           2    10  10  10    NaN
# 2           3    10  10  10    NaN
# 3           4    10  10  10    NaN
# 4           5    10  10  10    NaN
# ..        ...   ...  ..  ..    ...
# 210       211    10  10  10    NaN
# 211       212    10  10  10    NaN
# 212       213    10  10  10    NaN
# 213       214    10  10  10    NaN
# 214       215    10  10  10    NaN
#
# [215 rows x 5 columns]

# %%
df
# Out:
#    subject  Marks    1
# 0    maths    100  100
# 1  english     95  100
# 2  science     98  100
# 3    hindi     85  100

# %%
df.loc[0,"Marks"]=99

# %%
movie.loc[1,"movie"]="subham"
movie
# Out:
#                                         movie              lead  \
# 0                                     shubham     Vicky Kaushal
# 1                                      subham       Vicky Ahuja
# 2        The Accidental Prime Minister (film)       Anupam Kher
# 3                             Why Cheat India     Emraan Hashmi
# 4                             Evening Shadows  Mona Ambegaonkar
# ...                                       ...               ...
# 1497                          Saathiya (film)      Vivek Oberoi
# 1498                           Company (film)        Ajay Devgn
# 1499                     Awara Paagal Deewana      Akshay Kumar
# shubham                                subham               NaN
# 1                                      subham               NaN
#
#         Uri: The Surgical Strike
# 0                        shubham
# 1                            NaN
# 2                            NaN
# 3                            NaN
# ...

# %%
df.loc[2:3,"Marks"]=[100,98]
df
# Out:
#    subject  Marks    1  maths  (0, maths)  MArks  english  (0, Marks)
# 0    maths     99  100     97          97   97.0       97          99
# 1  english     95  100     97          97    NaN       97          99
# 2  science    100  100     97          97    NaN       97          99
# 3    hindi     98  100     97          97    NaN       97          99

# %%
df
# Out:
#    subject  Marks    1  maths  (0, maths)  MArks  english  (0, Marks)
# 0    maths     99  100     97          97   97.0       97          99
# 1  english     95  100     97          97    NaN       97          99
# 2  science     98  100     97          97    NaN       97          99
# 3    hindi     85  100     97          97    NaN       97          99

# %%
vk.iloc[[1,4]]=
# Out:
#    match_no   runs   0   1  Marks   4
# 1      98.0   98.0  99  99   98.0 NaN
# 4      98.0  100.0  99  99   98.0 NaN

# %%
df.iloc[[0,1]]
# Out:
#    subject  Marks    1  maths  (0, maths)  MArks  english  (0, Marks)
# 0    maths     99  100     97          97   97.0       97          99
# 1  english     95  100     97          97    NaN       97          99

# %%
df.loc[0,"Marks"]=98
df
# Out:
#    subject  Marks    1  maths  (0, maths)  MArks  english  (0, Marks)
# 0    maths     98  100     97          97   97.0       97          99
# 1  english     95  100     97          97    NaN       97          99
# 2  science    100  100     97          97    NaN       97          99
# 3    hindi     98  100     97          97    NaN       97          99

# %%
print(len(sub))
print(type(sub))
print(dir(sub))
print(sorted(sub))
print(min(sub))
# Out:
# 365
# <class 'pandas.core.frame.DataFrame'>
# ...

# %%
vk.min()
# Out:
# match_no      3.0
# runs         10.0
# 0            99.0
# 1            99.0
# Marks        98.0
# 4           100.0
# dtype: float64

# %%
sub["Subscribers gained"].min()
# Out:
# 33

# %%
df
# Out:
#    subject  Marks    1  maths  (0, maths)  MArks  english  (0, Marks)
# 0    maths     98  100     97          97   97.0       97          99
# 1  english     95  100     97          97    NaN       97          99
# 2  science    100  100     97          97    NaN       97          99
# 3    hindi     98  100     97          97    NaN       97          99

# %%
df['Marks'].min()
# Out:
# 95

# %%
movie
# Out:
#                                         movie              lead  \
# 0                                     shubham     Vicky Kaushal
# 1                                      subham       Vicky Ahuja
# 2        The Accidental Prime Minister (film)       Anupam Kher
# 3                             Why Cheat India     Emraan Hashmi
# 4                             Evening Shadows  Mona Ambegaonkar
# ...                                       ...               ...
# 1497                          Saathiya (film)      Vivek Oberoi
# 1498                           Company (film)        Ajay Devgn
# 1499                     Awara Paagal Deewana      Akshay Kumar
# shubham                                subham               NaN
# 1                                      subham               NaN
#
#         Uri: The Surgical Strike
# 0                        shubham
# 1                            NaN
# 2                            NaN
# 3                            NaN
# ...

# %%
sub
# Out:
#      Subscribers gained
# 0                    48
# 1                    57
# 2                    40
# 3                    43
# 4                    44
# ..                  ...
# 360                 231
# 361                 226
# 362                 155
# 363                 144
# 364                 172
#
# [365 rows x 1 columns]

# %%
vk

# %%
vk["runs"].min()
# Out:
# 10.0

# %%
sub

# %%
sub(sub>)

# %%
list(vk)
# Out:
# ['match_no', 'runs', 0, 1, 'Marks', 4]

# %%
dict(vk)
# Out:
# {'match_no': 0        98.0
#  1        98.0
#  2         3.0
#  3         4.0
#  4        98.0
#          ...
#  211     212.0
#  212     213.0
#  213     214.0
#  214     215.0
#  runs      NaN
#  Name: match_no, Length: 216, dtype: float64,
#  'runs': 0        98.0
#  1        98.0
#  2        10.0
#  3        10.0
#  4       100.0
#          ...
#  211      10.0
#  212      10.0
#  213      10.0
#  214      10.0
#  runs      NaN
#  Name: runs, Length: 216, dtype: float64,
#  0: 0       99
#  1       99
#  2       99
#  3       99
#  4       99
#          ..
#  211     99
#  212     99
#  213     99
#  214     99
#  runs    99
#  Name: 0, Length: 216, dtype: int64,
#  1: 0       99
#  1       99
#  2       99
#  3       99
#  4       99
#          ..
#  211     99
#  212     99
#  213     99
#  214     99
#  runs    99
#  Name: 1, Length: 216, dtype: int64,
#  'Marks': 0       98.0
#  1       98.0
#  2        NaN
#  3        NaN
#  4       98.0
#          ...
#  211      NaN
# ...

# %%
"Why Cheat India" in movies
# Out:
# False

# %%
movies=movie
movies
# Out:
#                                         movie              lead  \
# 0                                     shubham     Vicky Kaushal
# 1                                      subham       Vicky Ahuja
# 2        The Accidental Prime Minister (film)       Anupam Kher
# 3                             Why Cheat India     Emraan Hashmi
# 4                             Evening Shadows  Mona Ambegaonkar
# ...                                       ...               ...
# 1497                          Saathiya (film)      Vivek Oberoi
# 1498                           Company (film)        Ajay Devgn
# 1499                     Awara Paagal Deewana      Akshay Kumar
# shubham                                subham               NaN
# 1                                      subham               NaN
#
#         Uri: The Surgical Strike
# 0                        shubham
# 1                            NaN
# 2                            NaN
# 3                            NaN
# ...

# %%
"shubham"in movies.values
# Out:
# True

# %%
df["Marks"]=100-df["Marks"]
df
# Out:
#    subject  Marks    1  maths  (0, maths)  MArks  english  (0, Marks)  marks  \
# 0    maths    210  100     97          97   97.0       97          99      0
# 1  english    205  100     97          97    NaN       97          99      5
# 2  science    210  100     97          97    NaN       97          99      0
# 3    hindi    208  100     97          97    NaN       97          99      2
#
#      p
# 0 -110
# 1 -105
# 2 -110
# 3 -108

# %%
df['Marks']>=300
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4085/2866932112.py in <cell line: 0>()
# ----> 1 df['Marks']>=300
#
# NameError: name 'df' is not defined

# %%
import pandas as pd

# %%
student=[[1,2],[4,5]]
pd.DataFrame(student,columns=["1","2","2"])
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/internals/construction.py in _finalize_columns_and_data(content, columns, dtype)
#     938     try:
# --> 939         columns = _validate_or_indexify_columns(contents, columns)
#     940     except AssertionError as err:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/internals/construction.py in _validate_or_indexify_columns(content, columns)
#     985             # caller's responsibility to check for this...
# --> 986             raise AssertionError(
#     987                 f"{len(columns)} columns passed, passed data had "
#
# AssertionError: 3 columns passed, passed data had 2 columns
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# ...

# %%
s=[[1,1,1]]
pd.DataFrame(s,columns=[1,2,3])
# Out:
#    1  2  3
# 0  1  1  1

# %%
 student=[[1,2,2],[1,2,2]]
 pd.DataFrame(student,columns=["iq","s","l"])
# Out:
#    iq  s  l
# 0   1  2  2
# 1   1  2  2

# %%
pd.DataFrame(student,columns=["l","l","k"])
# Out:
#    l  l  k
# 0  1  2  2
# 1  1  2  2

# %%
student=[[1,20,20],[12,12,45]]
pd.DataFrame(student,columns=["b","j","k"])
# Out:
#     b   j   k
# 0   1  20  20
# 1  12  12  45

# %%
pd.DataFrame(student,columns=["o","p","p"])
# Out:
#     o   p   p
# 0   1  20  20
# 1  12  12  45

# %%
pd.DataFrame(student,columns=["p","p","o"])
# Out:
#     p   p   o
# 0   1  20  20
# 1  12  12  45

# %%
pd.DataFrame(student,columns=["l","l","m"])
# Out:
#     l   l   m
# 0   1  20  20
# 1  12  12  45

# %%
pd.DataFrame(student,columns=["k","p","s"])
# Out:
#     k   p   s
# 0   1  20  20
# 1  12  12  45

# %%
student_dict={"iq":[1,4],"m":[45,9],"pac":[4,8]}
pd.DataFrame(student_dict)
# Out:
#    iq   m  pac
# 0   1  45    4
# 1   4   9    8

# %%
student_s={
    "iq":[1,5],

    "ik":[2,5]
}
pd.DataFrame(student_s)
# Out:
#    iq  ik
# 0   1   2
# 1   5   5

# %%
 movies=pd.read_csv("/content/movies.csv")

# %%
movies
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
movies.shape
# Out:
# (1629, 18)

# %%
student={"p":[1,5,1,2],"l":[15,21,35,5]}
pd.DataFrame(student)
# Out:
#    p   l
# 0  1  15
# 1  5  21
# 2  1  35
# 3  2   5

# %%
movies.dtypes
# Out:
# title_x              object
# imdb_id              object
# poster_path          object
# wiki_link            object
# title_y              object
# original_title       object
# is_adult              int64
# year_of_release       int64
# runtime              object
# genres               object
# imdb_rating         float64
# imdb_votes            int64
# story                object
# summary              object
# tagline              object
# actors               object
# wins_nominations     object
# release_date         object
# dtype: object

# %%
movies.index
# Out:
# RangeIndex(start=0, stop=1629, step=1)

# %%
movies.sample()
# Out:
#      title_x    imdb_id                                        poster_path  \
# 313  Madaari  tt5713232  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                  wiki_link  title_y original_title  is_adult  \
# 313  https://en.wikipedia.org/wiki/Madaari  Madaari        Madaari         0
#
#      year_of_release runtime                    genres  imdb_rating  \
# 313             2016     133  Adventure|Drama|Thriller          7.5
#
#      imdb_votes                                              story  \
# 313       11411  'Madaari' is the story of a common man who set...
#
#                                                summary tagline  \
# 313  When Nirmal loses his family in a disaster cau...     NaN
#
#                                                 actors wins_nominations  \
# 313  Irrfan Khan|Jimmy Sheirgill|Vishesh Bansal|Tus...              NaN
#
#              release_date
# 313  22 July 2016 (India)

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1629 entries, 0 to 1628
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title_x           1629 non-null   object
#  1   imdb_id           1629 non-null   object
#  2   poster_path       1526 non-null   object
#  3   wiki_link         1629 non-null   object
#  4   title_y           1629 non-null   object
#  5   original_title    1629 non-null   object
#  6   is_adult          1629 non-null   int64
#  7   year_of_release   1629 non-null   int64
#  8   runtime           1629 non-null   object
#  9   genres            1629 non-null   object
#  10  imdb_rating       1629 non-null   float64
#  11  imdb_votes        1629 non-null   int64
#  12  story             1609 non-null   object
#  13  summary           1629 non-null   object
#  14  tagline           557 non-null    object
#  15  actors            1624 non-null   object
# ...

# %%
 movies.values
# Out:
# array([['Uri: The Surgical Strike', 'tt8291224',
#         'https://upload.wikimedia.org/wikipedia/en/thumb/3/3b/URI_-_New_poster.jpg/220px-URI_-_New_poster.jpg',
#         ...,
#         'Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Gautam|Kirti Kulhari|Rajit Kapoor|Ivan Rodrigues|Manasi Parekh|Swaroop Sampat|Riva Arora|Yogesh Soman|Fareed Ahmed|Akashdeep Arora|Kallol Banerjee|',
#         '4 wins', '11 January 2019 (USA)'],
#        ['Battalion 609', 'tt9472208', nan, ...,
#         'Vicky Ahuja|Shoaib Ibrahim|Shrikant Kamat|Elena Kazan|Vishwas Kini|Major Kishore|Jashn Kohli|Rammy C. Pandey|Manish Sharma|Sparsh Sharma|Farnaz Shetty|Vikas Shrivastav|Chandraprakash Thakur|Brajesh Tiwari|',
#         nan, '11 January 2019 (India)'],
#        ['The Accidental Prime Minister (film)', 'tt6986710',
#         'https://upload.wikimedia.org/wikipedia/en/thumb/a/a1/The_Accidental_Prime_Minister_film.jpg/220px-The_Accidental_Prime_Minister_film.jpg',
#         ...,
# ...

# %%
movies.describe()
# Out:
#        is_adult  year_of_release  imdb_rating     imdb_votes
# count    1629.0      1629.000000  1629.000000    1629.000000
# mean        0.0      2010.263966     5.557459    5384.263352
# std         0.0         5.381542     1.567609   14552.103231
# min         0.0      2001.000000     0.000000       0.000000
# 25%         0.0      2005.000000     4.400000     233.000000
# 50%         0.0      2011.000000     5.600000    1000.000000
# 75%         0.0      2015.000000     6.800000    4287.000000
# max         0.0      2019.000000     9.400000  310481.000000

# %%
movies.isnull().sum()
# Out:
# title_x                0
# imdb_id                0
# poster_path          103
# wiki_link              0
# title_y                0
# original_title         0
# is_adult               0
# year_of_release        0
# runtime                0
# genres                 0
# imdb_rating            0
# imdb_votes             0
# story                 20
# summary                0
# tagline             1072
# actors                 5
# wins_nominations     922
# release_date         107
# dtype: int64

# %%
j={"s":[1,2,0,0],"h":[1,2,0,0]}
o=pd.DataFrame(j)
o
# Out:
#    s  h
# 0  1  1
# 1  2  2
# 2  0  0
# 3  0  0

# %%
o.duplicated().sum()
# Out:
# np.int64(1)

# %%
o.rename(columns={"h":"id"})
# Out:
#    s  id
# 0  1   1
# 1  2   2
# 2  0   0
# 3  0   0

# %%
o
# Out:
#    s  h
# 0  1  1
# 1  2  2
# 2  0  0
# 3  0  0

# %%
o.rename(columns={"iq":"K","id":"p"})
# Out:
#    s  h
# 0  1  1
# 1  2  2
# 2  0  0
# 3  0  0

# %%
o.rename(columns={"j":"p"})
# Out:
#    p  h
# 0  1  1
# 1  2  2
# 2  0  0
# 3  0  0

# %%
o.rename(columns={"j":"k"},inplace=True)

# %%
o
# Out:
#    k  h
# 0  1  1
# 1  2  2
# 2  0  0
# 3  0  0

# %%
o.rename(columns={"k":"l","h":"o"})
# Out:
#    l  o
# 0  1  1
# 1  2  2
# 2  0  0
# 3  0  0

# %%
import pandas as pd

df = pd.DataFrame({
    "Name": ["Virat", "Rohit", "Gill", "Rahul", "Pant"],
    "Runs": [13848, 11168, 2500, 3000, 2800],
    "Matches": [302, 273, 55, 80, 75],
    "Average": [58.2, 48.7, 50.0, 42.5, 39.8]
})

print(df)
# Out:
#     Name   Runs  Matches  Average
# 0  Virat  13848      302     58.2
# 1  Rohit  11168      273     48.7
# 2   Gill   2500       55     50.0
# 3  Rahul   3000       80     42.5
# 4   Pant   2800       75     39.8

# %%
df.loc["Virat":"Gill"]
# Out:
# Empty DataFrame
# Columns: [Name, Runs, Matches, Average]
# Index: []

# %%
del df

# %%
df
# Out:
#     Name   Runs  Matches  Average
# 0  Virat  13848      302     58.2
# 1  Rohit  11168      273     48.7
# 2   Gill   2500       55     50.0
# 3  Rahul   3000       80     42.5
# 4   Pant   2800       75     39.8

# %%
df.set_index("Name").loc["Virat":"Pant":2]
# Out:
#         Runs  Matches  Average
# Name
# Virat  13848      302     58.2
# Gill    2500       55     50.0
# Pant    2800       75     39.8

# %%
d=df.set_index("Name")

# %%
d.loc["Virat":"Rohit"]
# Out:
#         Runs  Matches  Average
# Name
# Virat  13848      302     58.2
# Rohit  11168      273     48.7

# %%
do=df.set_index("Runs")

# %%
do
# Out:
#         Name  Matches  Average
# Runs
# 13848  Virat      302     58.2
# 11168  Rohit      273     48.7
# 2500    Gill       55     50.0
# 3000   Rahul       80     42.5
# 2800    Pant       75     39.8

# %%
do.loc[13848:3000]
# Out:
#         Name  Matches  Average
# Runs
# 13848  Virat      302     58.2
# 11168  Rohit      273     48.7
# 2500    Gill       55     50.0
# 3000   Rahul       80     42.5

# %%
del df

# %%
df.sort_values("Runs")
# Out:
#     Name   Runs  Matches  Average
# 2   Gill   2500       55     50.0
# 4   Pant   2800       75     39.8
# 3  Rahul   3000       80     42.5
# 1  Rohit  11168      273     48.7
# 0  Virat  13848      302     58.2

# %%
df.sort_values(by="Runs", inplace=True)

# %%
df
# Out:
#     Name   Runs  Matches  Average
# 2   Gill   2500       55     50.0
# 4   Pant   2800       75     39.8
# 3  Rahul   3000       80     42.5
# 1  Rohit  11168      273     48.7
# 0  Virat  13848      302     58.2

# %%
d.loc[["Virat","Pant"]]
# Out:
#         Runs  Matches  Average
# Name
# Virat  13848      302     58.2
# Pant    2800       75     39.8

# %%
df
# Out:
#     Name   Runs  Matches  Average
# 0  Virat  13848      302     58.2
# 1  Rohit  11168      273     48.7
# 2   Gill   2500       55     50.0
# 3  Rahul   3000       80     42.5
# 4   Pant   2800       75     39.8

# %%
d
# Out:
#         Runs  Matches  Average
# Name
# Virat  13848      302     58.2
# Rohit  11168      273     48.7
# Gill    2500       55     50.0
# Rahul   3000       80     42.5
# Pant    2800       75     39.8
